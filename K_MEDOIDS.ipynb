# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-528fcc21-f5f1-4a38-ba13-f137e904b662" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-528fcc21-f5f1-4a38-ba13-f137e904b662">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('/content/Mall_Customers.csv')

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df = df.drop("CustomerID", axis=1)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.scatter(df["Annual Income (k$)"],
            df["Spending Score (1-100)"],
            c=clusters,
            cmap="viridis",
            s=80)

plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score (1-100)")
plt.title("K-Medoids Clustering")
plt.colorbar(label="Cluster")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14168/4285560074.py in <cell line: 0>()
#       4 plt.scatter(df["Annual Income (k$)"],
#       5             df["Spending Score (1-100)"],
# ----> 6             c=clusters,
#       7             cmap="viridis",
#       8             s=80)
#
# NameError: name 'clusters' is not defined

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df["Gender"] = le.fit_transform(df["Gender"])   # Male=1, Female=0

# %%
df["Income_per_Age"] = df["Annual Income (k$)"] / (df["Age"] + 1)

df["Spending_Income_Ratio"] = df["Spending Score (1-100)"] / (df["Annual Income (k$)"] + 1)

df["Age_Group"] = pd.cut(
    df["Age"],
    bins=[0, 25, 40, 60, 100],
    labels=[0, 1, 2, 3]
).astype(int)

df["Customer_Value"] = (
    df["Annual Income (k$)"] *
    df["Spending Score (1-100)"]
) / 100

# %%
df.shape
# Out:
# (200, 8)

# %%
df.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)  Income_per_Age  \
# 0       1   19                  15                      39        0.750000
# 1       1   21                  15                      81        0.681818
# 2       0   20                  16                       6        0.761905
# 3       0   23                  16                      77        0.666667
# 4       0   31                  17                      40        0.531250
#
#    Spending_Income_Ratio  Age_Group  Customer_Value
# 0               2.437500          0            5.85
# 1               5.062500          0           12.15
# 2               0.352941          0            0.96
# 3               4.529412          0           12.32
# 4               2.222222          1            6.80

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(df)

# %%
# !pip uninstall -y numpy scikit-learn-extra # Uninstall existing versions to avoid conflicts
# !pip install scikit-learn-extra
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Found existing installation: scikit-learn-extra 0.3.0
# Uninstalling scikit-learn-extra-0.3.0:
#   Successfully uninstalled scikit-learn-extra-0.3.0
# ...
#   Using cached scikit_learn_extra-0.3.0-cp312-cp312-linux_x86_64.whl
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 56.5 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.5.0 which is incompatible.
# ...

# %%
# !pip uninstall -y numpy scikit-learn-extra
# !pip install numpy==1.26.4
# !pip install scikit-learn-extra==0.3.0
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Found existing installation: scikit-learn-extra 0.3.0
# Uninstalling scikit-learn-extra-0.3.0:
#   Successfully uninstalled scikit-learn-extra-0.3.0
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# shap 0.52.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
from sklearn_extra.cluster import KMedoids

# %%
# !pip install kmedoids

# %%
import kmedoids

# %%
X = df.drop("Cluster", axis=1, errors="ignore")

# %%
X = df.copy()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(
    X,
    test_size=0.2,
    random_state=42
)

from sklearn_extra.cluster import KMedoids

kmedoids = KMedoids(
    n_clusters=5,
    random_state=42
)

kmedoids.fit(X_train)

train_clusters = kmedoids.predict(X_train)
test_clusters = kmedoids.predict(X_test)

# %%
from sklearn_extra.cluster import KMedoids

kmedoids = KMedoids(
    n_clusters=5,
    random_state=42
)

clusters = kmedoids.fit_predict(X)

# %%
from sklearn.metrics import silhouette_score

score = silhouette_score(X, clusters)

print("Silhouette Score:", score)
# Out:
# Silhouette Score: 0.4319220539571975

# %%
from sklearn_extra.cluster import KMedoids
from sklearn.metrics import silhouette_score

for k in range(2, 11):
    model = KMedoids(n_clusters=k, random_state=42)
    labels = model.fit_predict(X)
    score = silhouette_score(X, labels)
    print(f"k = {k}, Silhouette Score = {score:.4f}")
# Out:
# k = 2, Silhouette Score = 0.3035
# k = 3, Silhouette Score = 0.2711
# k = 4, Silhouette Score = 0.3018
# k = 5, Silhouette Score = 0.4319
# k = 6, Silhouette Score = 0.4078
# k = 7, Silhouette Score = 0.3664
# k = 8, Silhouette Score = 0.3788
# k = 9, Silhouette Score = 0.3779
# k = 10, Silhouette Score = 0.3653

# %%
from sklearn.metrics import silhouette_score

score = silhouette_score(X, clusters)

print("Silhouette Score:", score)
# Out:
# Silhouette Score: 0.4319220539571975

# %%
from sklearn_extra.cluster import KMedoids
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Define X_scaled locally for this cell, as per JhCRboa0UwbK
temp_X_for_scaling = df[["Annual Income (k$)", "Spending Score (1-100)"]]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(temp_X_for_scaling)

best_score = -1
best_k = 2

for k in range(2, 11):
    model = KMedoids(n_clusters=k, random_state=42)
    labels = model.fit_predict(X_scaled)
    score = silhouette_score(X_scaled, labels)
    print(f"k={k}, Score={score:.4f}")

    if score > best_score:
        best_score = score
        best_k = k

print("\nBest K:", best_k)
print("Best Score:", best_score)
# Out:
# k=2, Score=0.2876
# k=3, Score=0.3764
# k=4, Score=0.4930
# k=5, Score=0.4476
# k=6, Score=0.1923
# k=7, Score=0.4073
# k=8, Score=0.3712
# k=9, Score=0.3521
# k=10, Score=0.3515
#
# Best K: 4
# Best Score: 0.49301598881553493

# %%
X = df[["Annual Income (k$)", "Spending Score (1-100)"]]

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.metrics import silhouette_score

score = silhouette_score(X, clusters)

print("Silhouette Score:", score)
# Out:
# Silhouette Score: 0.5063636535071422
